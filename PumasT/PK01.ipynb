# %% [markdown]
# ## Exercise PK01 - One Compartment Intravenous Bolus Dosing

# %% [markdown]
# - Structural model - One compartment linear elimination
#
# - Route of administration - IV bolus
#
# - Dosage Regimen - 10 mg IV
#
# - Number of Subjects - 4

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
using Pumas
using PumasUtilities
using Random
using CairoMakie
# Out:
# ArgumentError: Package Pumas [4f2c3c20-a4ac-11e9-067b-e5872d3484cf] is required but does not seem to be installed:
#
#  - Run `Pkg.instantiate()` to install all recorded dependencies.
#
#
#
#
#
# Stacktrace:
#
#   [1] _require(pkg::Base.PkgId, env::String)
#
#     @ Base .\loading.jl:1774
#
#   [2] _require_prelocked(uuidkey::Base.PkgId, env::String)
#
#     @ Base .\loading.jl:1660
#
#   [3] macro expansion
#
#     @ .\loading.jl:1648 [inlined]
#
#   [4] macro expansion
#
#     @ .\lock.jl:267 [inlined]
#
#   [5] require(into::Module, mod::Symbol)
#
#     @ Base .\loading.jl:1611
#
#   [6] eval
#
#     @ .\boot.jl:370 [inlined]
#
#   [7] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#
#     @ Base .\loading.jl:1903
#
#   [8] #invokelatest#2
#
#     @ .\essentials.jl:816 [inlined]
#
#   [9] invokelatest
#
#     @ .\essentials.jl:813 [inlined]
#
#  [10] (::VSCodeServer.var"#208#209"{VSCodeServer.NotebookRunCellArguments, String})()
#
#     @ VSCodeServer c:\Users\m1825\.vscode\extensions\julialang.language-julia-1.66.2\scripts\packages\VSCodeServer\src\serve_notebook.jl:19
#
#  [11] withpath(f::VSCodeServer.var"#208#209"{VSCodeServer.NotebookRunCellArguments, String}, path::String)
#
#     @ VSCodeServer c:\Users\m1825\.vscode\extensions\julialang.language-julia-1.66.2\scripts\packages\VSCodeServer\src\repl.jl:274
#
#  [12] notebook_runcell_request(conn::VSCodeServer.JSONRPC.JSONRPCEndpoint{Base.PipeEndpoint, Base.PipeEndpoint}, params::VSCodeServer.NotebookRunCellArguments)
#
#     @ VSCodeServer c:\Users\m1825\.vscode\extensions\julialang.language-julia-1.66.2\scripts\packages\VSCodeServer\src\serve_notebook.jl:13
#
#  [13] dispatch_msg(x::VSCodeServer.JSONRPC.JSONRPCEndpoint{Base.PipeEndpoint, Base.PipeEndpoint}, dispatcher::VSCodeServer.JSONRPC.MsgDispatcher, msg::Dict{String, Any})
#
#     @ VSCodeServer.JSONRPC c:\Users\m1825\.vscode\extensions\julialang.language-julia-1.66.2\scripts\packages\JSONRPC\src\typed.jl:67
#
#  [14] serve_notebook(pipename::String, outputchannel_logger::Base.CoreLogging.SimpleLogger; crashreporting_pipename::String)
#
#     @ VSCodeServer c:\Users\m1825\.vscode\extensions\julialang.language-julia-1.66.2\scripts\packages\VSCodeServer\src\serve_notebook.jl:139
#
#  [15] top-level scope
#
#     @ c:\Users\m1825\.vscode\extensions\julialang.language-julia-1.66.2\scripts\notebook\notebook.jl:32
